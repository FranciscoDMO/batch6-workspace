# %% [markdown]
# # BLU06  - Exercise Notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
idx = pd.IndexSlice
warnings.simplefilter(action='ignore', category=FutureWarning)   
from random import seed
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import mean_squared_error
import math
from sklearn.ensemble import GradientBoostingRegressor
import itertools
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa import stattools
import hashlib # for grading purposes
from sklearn.model_selection import ParameterGrid
from tqdm.notebook import tqdm

from pandas.plotting import lag_plot
plt.rcParams['figure.figsize'] = (12, 4)

from utils import *

# %matplotlib inline

# %% [markdown]
# # Let's predict wind power production!

# %%
df = pd.read_csv('data/wind_power.csv')
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')
df = df.sort_index()

# %% [markdown]
# ##### Plot the series to get an idea of what's going on

# %%
df.plot(figsize=(16, 4));
plt.ylabel('wind power')
plt.title('Wind power production for the initial months of 2010')
plt.show()

# %% [markdown]
# ### Q1: Formulate it as time series one-step-ahead prediction

# %% [markdown]
# ### Q1.1 Create the target, the relevant lags and drop the missing values.

# %%
plot_pacf(df)

# %%
df
# Out:
#                         wp
# date
# 2010-01-01 00:00:00  0.085
# 2010-01-01 01:00:00  0.065
# 2010-01-01 02:00:00  0.080
# 2010-01-01 03:00:00  0.095
# 2010-01-01 04:00:00  0.095
# ...                    ...
# 2010-03-31 19:00:00  0.135
# 2010-03-31 20:00:00  0.160
# 2010-03-31 21:00:00  0.256
# 2010-03-31 22:00:00  0.271
# 2010-03-31 23:00:00  0.286
#
# [2160 rows x 1 columns]

# %%
# Note: By relevant lags we expect you to assume the top 3 lags from the PACF (including negatively correlated ones).
# Remember from the previous BLU to look at the PACF you only need to run plot_pacf(df)

df_features = df.copy()
df_features['lag_a'] = df.wp.shift(1)
df_features['lag_b'] = df.wp.shift(2)
df_features['lag_c'] = df.wp.shift(25)
df_features['target'] = df.wp.shift(-1)
#df_features = df_features.drop(columns = 'wp' , axis=1)
df_features=df_features.dropna()
#df_features =  [feature for feature in df_features.columns if feature != target]
df_features.shape
# Out:
# (2134, 5)

# %%
expected_hash = '6e7c3f337212b8e01b67b3d63a2597b35850076095277e4cd323c07a33d02b93'
assert hashlib.sha256(str(df_features.shape).encode()).hexdigest() == expected_hash

expected_hash = 'e5351d4cf12cd01d360938a341d09da9cf5728ac1902133344147fbcab933fdc'
assert hashlib.sha256(str(df_features.iloc[0]).encode()).hexdigest() == expected_hash

# %% [markdown]
# ### Q1.2 Separate the training and test set. The test set consists of the last 24 values, while the training set consists of the rest.

# %%
#note: this is a very straightforward question. But you may think: "isn't this one-step-ahead forecasting? 
#Why does the test have 24 values" Well, basically this just means we are doing 24 one-step-ahead forecasts.
#This way we obtain a better estimate of how our one-step-ahead model would perform in the real world.
last_period = df_features.iloc[-24]

df_train = df_features.loc[df_features.index < last_period.name]
df_test = df_features.tail(24)

# %%
expected_hash = '4645890e7eab6608a2037bae3d98cba5a58ed02bf55ca030aa721ed1c68f7403'
assert hashlib.sha256(str(df_train.index[-1]).encode()).hexdigest() == expected_hash

expected_hash = '49a4f69687c306f42ebbc05f79ad78ab8c963cbe20e98fc11cb77629fa6b7259'
assert hashlib.sha256(str(df_test.index[0]).encode()).hexdigest() == expected_hash

# %% [markdown]
# ### Q1.3 Fit a linear regression to the training set

# %%
y_df_train = df_train.target

X_df_train = df_train.drop(columns = 'target' , axis = 1 )


model = LinearRegression()
model.fit(X_df_train,y_df_train)
X_df_train
# Out:
#                         wp  lag_a  lag_b  lag_c
# date
# 2010-01-02 01:00:00  0.401  0.411  0.441  0.085
# 2010-01-02 02:00:00  0.431  0.401  0.411  0.065
# 2010-01-02 03:00:00  0.416  0.431  0.401  0.080
# 2010-01-02 04:00:00  0.396  0.416  0.431  0.095
# 2010-01-02 05:00:00  0.411  0.396  0.416  0.095
# ...                    ...    ...    ...    ...
# 2010-03-30 18:00:00  0.000  0.000  0.000  0.175
# 2010-03-30 19:00:00  0.000  0.000  0.000  0.211
# 2010-03-30 20:00:00  0.000  0.000  0.000  0.145
# 2010-03-30 21:00:00  0.025  0.000  0.000  0.115
# 2010-03-30 22:00:00  0.080  0.025  0.000  0.060
#
# [2110 rows x 4 columns]

# %%
expected_hash = '1f7448e98bdb7d0ec574b34ef1478a0a170a96448be5ef3dfa3ba426fd2a4e9d'
assert hashlib.sha256(str(X_df_train.shape).encode()).hexdigest() == expected_hash

expected_hash = '0e39cad2ee7a31366699e40633f45b99f0211f1734d40dab9d2c5fb461ab7aa7'
assert hashlib.sha256(str(y_df_train.shape).encode()).hexdigest() == expected_hash

expected_hash = '2211e7e3e265cdb6e1337bbc7deac40ed9cd0c3203e70fded127c801e783b5f2'
assert hashlib.sha256(str(np.round(model.coef_,1)).encode()).hexdigest() == expected_hash

# %% [markdown]
# ### Q1.4 Predict the test set and calculate the MAE

# %%
y_df_test = df_test.target
X_df_test = df_test.drop(columns = 'target' , axis = 1 )

y_predict = model.predict(X_df_test)

test_mae = mean_absolute_error(y_predict,y_df_test)

# %%
expected_hash = '4b259a01aeaa99e670a865121f78c1d76f029cd5158b51c72089c0bd254d17a1'
assert hashlib.sha256(str(X_df_test.shape).encode()).hexdigest() == expected_hash

expected_hash = '46ff29167351b465ba887b52b52ebddfd407ee7c8781d11225ad285541d89be5'
assert hashlib.sha256(str(y_df_test.shape).encode()).hexdigest() == expected_hash

expected_hash = '64b1c7c2dc78c85eb25fc8ebbbe7b3f27095df61f7b0621c64be58a55a042cc6'
assert hashlib.sha256(str(np.round(test_mae,5)).encode()).hexdigest() == expected_hash

# %% [markdown]
# ### Q2 Let's go into multi-step prediction!

# %% [markdown]
# ### Q2.1 Separate into train, val and test. Test corresponds to the last 24 values and Val corresponds to the 24 steps before test.

# %%
df
# Out:
#                         wp
# date
# 2010-01-01 00:00:00  0.085
# 2010-01-01 01:00:00  0.065
# 2010-01-01 02:00:00  0.080
# 2010-01-01 03:00:00  0.095
# 2010-01-01 04:00:00  0.095
# ...                    ...
# 2010-03-31 19:00:00  0.135
# 2010-03-31 20:00:00  0.160
# 2010-03-31 21:00:00  0.256
# 2010-03-31 22:00:00  0.271
# 2010-03-31 23:00:00  0.286
#
# [2160 rows x 1 columns]

# %%
last_period = df_features.iloc[-24]

df_train = df_features.loc[df_features.index < last_period.name]
df_test = df_features.tail(24)

# %%
last_period_test = df.iloc[-24]
last_period_val = df.iloc[-48]


df_multistep_train = df.loc[df.index < last_period_val.name]
df_multistep_val =df.loc[ (last_period_val.name <= df.index) & (df.index < last_period_test.name)]
df_multistep_test = df.tail(24)

# %%
x = (5000,3)

while(True):
    s,y = x 
    s=s-1
    x = (s,y)
    
    if(hashlib.sha256(str(x).encode()).hexdigest() == expected_hash):
        print(x)
        break
        
    if( s== 0):
        x=(5000,y-1)
        if(y==0):
            print('didnt work')
            print(x)
            break
# Out:
# didnt work
# (5000, -1)

# %%
expected_hash = 'b9202ef2e8ac88d956f6a0fc0b5c83540a0568fc2a19b5941796f3b140d84419'
assert hashlib.sha256(str(df_multistep_train.shape).encode()).hexdigest() == expected_hash

expected_hash = '17511d2ef2dbcb5be2ccb6880d9c364c156770484a5cf8292dfe283ea2405125'
assert hashlib.sha256(str(df_multistep_val.shape).encode()).hexdigest() == expected_hash

expected_hash = '17511d2ef2dbcb5be2ccb6880d9c364c156770484a5cf8292dfe283ea2405125'
assert hashlib.sha256(str(df_multistep_test.shape).encode()).hexdigest() == expected_hash

# %% [markdown]
# ### Q2.2 Let's test some hyperparameter optimization!

# %%
df_multistep_train.wp
# Out:
# date
# 2010-01-01 00:00:00    0.085
# 2010-01-01 01:00:00    0.065
# 2010-01-01 02:00:00    0.080
# 2010-01-01 03:00:00    0.095
# 2010-01-01 04:00:00    0.095
#                        ...
# 2010-03-29 19:00:00    0.145
# 2010-03-29 20:00:00    0.115
# 2010-03-29 21:00:00    0.060
# 2010-03-29 22:00:00    0.045
# 2010-03-29 23:00:00    0.060
# Name: wp, Length: 2112, dtype: float64

# %%
# %%time

# Create a parameter grid with the following conditions:
#    - Include the linear regression and gradient boosting regressor models. 
#      For the gradient boosting regressor use n_estimators=20 and random_state=10
#    - Test using 3 and 26 lags
#    - Test using 0 or 15 periods diffed
#    - Set the weekday, month and holidays to False. These shouldn't affect wind power.
#    - Don't use rollings.
# Use a for cycle to find the group of params that minimizes the MAE on the validation set.

# hint: to have no rollings in the predict_n_periods you should put an empty lists of lists in the param grid: [[]]

param_grid =  {'model': [ LinearRegression() , GradientBoostingRegressor(n_estimators=20,random_state=10) ], 
              'num_periods_lagged':[3,26],
              'num_periods_diffed':[0,15],
              'weekday':[False],
              'month':[False],
              'holidays': [False],
              'rolling' : [[]]
             }

grid = ParameterGrid(param_grid)
error_lst = []
params_lst = []
for params in grid:
    predictions = predict_n_periods(series_=df_multistep_train,
                                    n_periods = len(df_multistep_val),
                                    model = params['model'],
                                    num_periods_lagged = params['num_periods_lagged'],
                                    num_periods_diffed = params['num_periods_diffed'],
                                    weekday=params['weekday'],
                                    month= params['month'],
                                    target = "wp"
                                   )
    error_lst.append( mean_absolute_error(df_multistep_val,predictions))
    
                   
                                    
best_params= error_lst
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# CPU times: user 32.6 s, sys: 14.6 s, total: 47.2 s
# Wall time: 28.2 s

# %%
error_lst
# Out:
# [0.134743586854255,
#  0.14857147875819868,
#  0.1438285010257401,
#  0.1492790309078498,
#  0.14769686120991848,
#  0.16377733842977785,
#  0.13940600757150956,
#  0.14851582748866246]

# %%
best_params = grid[0]

# %%
expected_hash = '0c7f50ff83b085cd342a206e2c60d557601bddd1f378de106098f9350640d61e'
assert hashlib.sha256(str(best_params['model']).encode()).hexdigest() == expected_hash

expected_hash = '4e07408562bedb8b60ce05c1decfe3ad16b72230967de01f640b7e4729b49fce'
assert hashlib.sha256(str(best_params['num_periods_lagged']).encode()).hexdigest() == expected_hash

expected_hash = '5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91b46729d73a27fb57e9'
assert hashlib.sha256(str(best_params['num_periods_diffed']).encode()).hexdigest() == expected_hash

expected_hash = '60a33e6cf5151f2d52eddae9685cfa270426aa89d8dbc7dfb854606f1d1a40fe'
assert hashlib.sha256(str(best_params['weekday']).encode()).hexdigest() == expected_hash

expected_hash = '60a33e6cf5151f2d52eddae9685cfa270426aa89d8dbc7dfb854606f1d1a40fe'
assert hashlib.sha256(str(best_params['month']).encode()).hexdigest() == expected_hash

expected_hash = '60a33e6cf5151f2d52eddae9685cfa270426aa89d8dbc7dfb854606f1d1a40fe'
assert hashlib.sha256(str(best_params['holidays']).encode()).hexdigest() == expected_hash

expected_hash = '4f53cda18c2baa0c0354bb5f9a3ecbe5ed12ab4d8e11ba873c2f11161202b945'
assert hashlib.sha256(str(best_params['rolling']).encode()).hexdigest() == expected_hash

expected_hash = '7902699be42c8a8e46fbbb4501726517e86b22c56a189f7625a6da49081b2451'
assert hashlib.sha256(str(len(best_params)).encode()).hexdigest() == expected_hash

# %%
best_params
# Out:
# {'weekday': False,
#  'rolling': [],
#  'num_periods_lagged': 3,
#  'num_periods_diffed': 0,
#  'month': False,
#  'model': LinearRegression(),
#  'holidays': False}

# %% [markdown]
# ### Q2.3 Train a model with the best combination and predict the test set. Calculate the corresponding MAE.

# %%
# We expect you to train the final model with train and val together.

df_multistep_train_val = pd.concat([df_multistep_train, df_multistep_val]) 

predictions = predict_n_periods(series_=df_multistep_train_val, 
                  n_periods=len(df_multistep_test), 
                  model=best_params['model'], 
                  num_periods_lagged = best_params['num_periods_lagged'],
                  num_periods_diffed = best_params['num_periods_diffed'],
                  holidays = best_params['holidays'],
                  weekday=best_params['weekday'],
                  month= best_params['month'],
                  target='wp'
                                
                  )
test_mae =  mean_absolute_error(df_multistep_test,predictions)
test_mae
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# 0.13624044138329555

# %%
expected_hash = '389b9a7d9112bcd9a1b488224b030633d4e420fcabb1ebf9c839072046c2c4c4'
assert hashlib.sha256(str(np.round(test_mae,5)).encode()).hexdigest() == expected_hash

# %% [markdown]
# ### Q3 Finally, we'll add exogenous features to improve model performance!

# %%
exog = pd.read_csv('data/wind_speed_forecast.csv')
exog['date'] = pd.to_datetime(exog['date'])
exog = exog.set_index('date')
exog = exog.sort_index()

# %%
exog
# Out:
#                        ws
# date
# 2010-01-01 00:00:00  2.33
# 2010-01-01 01:00:00  2.44
# 2010-01-01 02:00:00  2.49
# 2010-01-01 03:00:00  2.54
# 2010-01-01 04:00:00  2.62
# ...                   ...
# 2010-03-31 19:00:00  3.56
# 2010-03-31 20:00:00  3.67
# 2010-03-31 21:00:00  4.01
# 2010-03-31 22:00:00  4.55
# 2010-03-31 23:00:00  5.09
#
# [2160 rows x 1 columns]

# %% [markdown]
# ### Q3.1 Add the exogenous feature to the dataset and the corresponding leads

# %%
# Remember you want to build a number of leads corresponding to the 24 values of the next day

df["exog"] = exog.ws
df = build_exog_features(df, 24)

df.shape
# Out:
# (2160, 26)

# %%
expected_hash = 'dc81d4b4ac58b278e08f7c97d999d52f0b6b2416fa6ee85c37371b65194b92e1'
assert hashlib.sha256(str(df.shape).encode()).hexdigest() == expected_hash

expected_hash = 'c958a8701a36c5c8de6af0e4be7643e2a11f603d1c7e08da1cbcc0717955b278'
assert hashlib.sha256(str(df).encode()).hexdigest() == expected_hash

# %% [markdown]
# ### Q3.2 Separate into train, val and test. Test corresponds to the last 24 values and Val corresponds to the 24 steps before test.

# %%
last_period_test = df.iloc[-24]
last_period_val = df.iloc[-48]


df_multistep_train = df.loc[df.index < last_period_val.name]
df_multistep_val =df.loc[ (last_period_val.name <= df.index) & (df.index < last_period_test.name)]
df_multistep_test = df.tail(24)

# %%
df_multistep_test
# Out:
#                         wp  exog  exog_lead1  exog_lead2  exog_lead3  \
# date
# 2010-03-31 00:00:00  0.090  5.62        4.35        3.73        3.07
# 2010-03-31 01:00:00  0.100  4.35        3.73        3.07        2.40
# 2010-03-31 02:00:00  0.075  3.73        3.07        2.40        1.79
# 2010-03-31 03:00:00  0.000  3.07        2.40        1.79        1.36
# 2010-03-31 04:00:00  0.000  2.40        1.79        1.36        0.97
# 2010-03-31 05:00:00  0.000  1.79        1.36        0.97        0.60
# 2010-03-31 06:00:00  0.000  1.36        0.97        0.60        0.73
# 2010-03-31 07:00:00  0.000  0.97        0.60        0.73        1.76
# 2010-03-31 08:00:00  0.000  0.60        0.73        1.76        2.90
# 2010-03-31 09:00:00  0.000  0.73        1.76        2.90        3.43
# 2010-03-31 10:00:00  0.000  1.76        2.90        3.43        2.93
# 2010-03-31 11:00:00  0.000  2.90        3.43        2.93        2.05
# 2010-03-31 12:00:00  0.000  3.43        2.93        2.05        1.71
# 2010-03-31 13:00:00  0.110  2.93        2.05        1.71        2.10
# 2010-03-31 14:00:00  0.070  2.05        1.71        2.10        2.77
# 2010-03-31 15:00:00  0.010  1.71        2.10        2.77        3.36
# 2010-03-31 16:00:00  0.000  2.10        2.77        3.36        3.56
# 2010-03-31 17:00:00  0.000  2.77        3.36        3.56        3.67
# 2010-03-31 18:00:00  0.040  3.36        3.56        3.67        4.01
# 2010-03-31 19:00:00  0.135  3.56        3.67        4.01        4.55
# 2010-03-31 20:00:00  0.160  3.67        4.01        4.55        5.09
# 2010-03-31 21:00:00  0.256  4.01        4.55        5.09         NaN
# 2010-03-31 22:00:00  0.271  4.55        5.09         NaN         NaN
# 2010-03-31 23:00:00  0.286  5.09         NaN         NaN         NaN
#
#                      exog_lead4  exog_lead5  exog_lead6  exog_lead7  \
# date
# 2010-03-31 00:00:00        2.40        1.79        1.36        0.97
# 2010-03-31 01:00:00        1.79        1.36        0.97        0.60
# 2010-03-31 02:00:00        1.36        0.97        0.60        0.73
# 2010-03-31 03:00:00        0.97        0.60        0.73        1.76
# 2010-03-31 04:00:00        0.60        0.73        1.76        2.90
# 2010-03-31 05:00:00        0.73        1.76        2.90        3.43
# 2010-03-31 06:00:00        1.76        2.90        3.43        2.93
# 2010-03-31 07:00:00        2.90        3.43        2.93        2.05
# 2010-03-31 08:00:00        3.43        2.93        2.05        1.71
# 2010-03-31 09:00:00        2.93        2.05        1.71        2.10
# 2010-03-31 10:00:00        2.05        1.71        2.10        2.77
# 2010-03-31 11:00:00        1.71        2.10        2.77        3.36
# 2010-03-31 12:00:00        2.10        2.77        3.36        3.56
# 2010-03-31 13:00:00        2.77        3.36        3.56        3.67
# 2010-03-31 14:00:00        3.36        3.56        3.67        4.01
# 2010-03-31 15:00:00        3.56        3.67        4.01        4.55
# 2010-03-31 16:00:00        3.67        4.01        4.55        5.09
# 2010-03-31 17:00:00        4.01        4.55        5.09         NaN
# 2010-03-31 18:00:00        4.55        5.09         NaN         NaN
# 2010-03-31 19:00:00        5.09         NaN         NaN         NaN
# 2010-03-31 20:00:00         NaN         NaN         NaN         NaN
# 2010-03-31 21:00:00         NaN         NaN         NaN         NaN
# 2010-03-31 22:00:00         NaN         NaN         NaN         NaN
# 2010-03-31 23:00:00         NaN         NaN         NaN         NaN
#
#                      exog_lead8  ...  exog_lead15  exog_lead16  exog_lead17  \
# date                             ...
# 2010-03-31 00:00:00        0.60  ...         1.71         2.10         2.77
# 2010-03-31 01:00:00        0.73  ...         2.10         2.77         3.36
# 2010-03-31 02:00:00        1.76  ...         2.77         3.36         3.56
# 2010-03-31 03:00:00        2.90  ...         3.36         3.56         3.67
# 2010-03-31 04:00:00        3.43  ...         3.56         3.67         4.01
# 2010-03-31 05:00:00        2.93  ...         3.67         4.01         4.55
# 2010-03-31 06:00:00        2.05  ...         4.01         4.55         5.09
# 2010-03-31 07:00:00        1.71  ...         4.55         5.09          NaN
# 2010-03-31 08:00:00        2.10  ...         5.09          NaN          NaN
# 2010-03-31 09:00:00        2.77  ...          NaN          NaN          NaN
# 2010-03-31 10:00:00        3.36  ...          NaN          NaN          NaN
# 2010-03-31 11:00:00        3.56  ...          NaN          NaN          NaN
# 2010-03-31 12:00:00        3.67  ...          NaN          NaN          NaN
# 2010-03-31 13:00:00        4.01  ...          NaN          NaN          NaN
# 2010-03-31 14:00:00        4.55  ...          NaN          NaN          NaN
# 2010-03-31 15:00:00        5.09  ...          NaN          NaN          NaN
# 2010-03-31 16:00:00         NaN  ...          NaN          NaN          NaN
# 2010-03-31 17:00:00         NaN  ...          NaN          NaN          NaN
# 2010-03-31 18:00:00         NaN  ...          NaN          NaN          NaN
# 2010-03-31 19:00:00         NaN  ...          NaN          NaN          NaN
# 2010-03-31 20:00:00         NaN  ...          NaN          NaN          NaN
# 2010-03-31 21:00:00         NaN  ...          NaN          NaN          NaN
# 2010-03-31 22:00:00         NaN  ...          NaN          NaN          NaN
# 2010-03-31 23:00:00         NaN  ...          NaN          NaN          NaN
#
#                      exog_lead18  exog_lead19  exog_lead20  exog_lead21  \
# date
# 2010-03-31 00:00:00         3.36         3.56         3.67         4.01
# 2010-03-31 01:00:00         3.56         3.67         4.01         4.55
# 2010-03-31 02:00:00         3.67         4.01         4.55         5.09
# 2010-03-31 03:00:00         4.01         4.55         5.09          NaN
# 2010-03-31 04:00:00         4.55         5.09          NaN          NaN
# 2010-03-31 05:00:00         5.09          NaN          NaN          NaN
# 2010-03-31 06:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 07:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 08:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 09:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 10:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 11:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 12:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 13:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 14:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 15:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 16:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 17:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 18:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 19:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 20:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 21:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 22:00:00          NaN          NaN          NaN          NaN
# 2010-03-31 23:00:00          NaN          NaN          NaN          NaN
#
#                      exog_lead22  exog_lead23  exog_lead24
# date
# 2010-03-31 00:00:00         4.55         5.09          NaN
# 2010-03-31 01:00:00         5.09          NaN          NaN
# 2010-03-31 02:00:00          NaN          NaN          NaN
# 2010-03-31 03:00:00          NaN          NaN          NaN
# 2010-03-31 04:00:00          NaN          NaN          NaN
# 2010-03-31 05:00:00          NaN          NaN          NaN
# 2010-03-31 06:00:00          NaN          NaN          NaN
# 2010-03-31 07:00:00          NaN          NaN          NaN
# 2010-03-31 08:00:00          NaN          NaN          NaN
# 2010-03-31 09:00:00          NaN          NaN          NaN
# 2010-03-31 10:00:00          NaN          NaN          NaN
# 2010-03-31 11:00:00          NaN          NaN          NaN
# 2010-03-31 12:00:00          NaN          NaN          NaN
# 2010-03-31 13:00:00          NaN          NaN          NaN
# 2010-03-31 14:00:00          NaN          NaN          NaN
# 2010-03-31 15:00:00          NaN          NaN          NaN
# 2010-03-31 16:00:00          NaN          NaN          NaN
# 2010-03-31 17:00:00          NaN          NaN          NaN
# 2010-03-31 18:00:00          NaN          NaN          NaN
# 2010-03-31 19:00:00          NaN          NaN          NaN
# 2010-03-31 20:00:00          NaN          NaN          NaN
# 2010-03-31 21:00:00          NaN          NaN          NaN
# 2010-03-31 22:00:00          NaN          NaN          NaN
# 2010-03-31 23:00:00          NaN          NaN          NaN
#
# [24 rows x 26 columns]

# %%
expected_hash = '2837155d68248a6d1b420e270ceed5dc0a593693ad57948e1fc4df01ecf97695'
assert hashlib.sha256(str(df_multistep_train.shape).encode()).hexdigest() == expected_hash

expected_hash = '87dc6044b1bf391af8f8cd3b7bc9022b8d2a4df90c38ca4b30cae58843788eb8'
assert hashlib.sha256(str(df_multistep_val.shape).encode()).hexdigest() == expected_hash

expected_hash = '87dc6044b1bf391af8f8cd3b7bc9022b8d2a4df90c38ca4b30cae58843788eb8'
assert hashlib.sha256(str(df_multistep_test.shape).encode()).hexdigest() == expected_hash

# %% [markdown]
# ### Q3.3 Let's test some hyperparameter optimisation (again)!

# %%
# %%time

# Create a parameter grid with the following conditions:
#    - Include the linear regression and gradient boosting regressor models. 
#      For the gradient boosting regressor use n_estimators=20 and random_state=10
#    - Test using 3 and 26 lags
#    - Set the periods diffed to 0
#    - Set the weekday, month and holidays to False. These shouldn't affect wind power.
#    - Don't use rollings.
# Use a for cycle to find the group of params that minimizes the MAE on the validation set.

# hint: This should be pretty much a copy paste from exercise 2.2. Remember that now our dataset has
#       exogenous features so we want to understand if the hyperparameter optimisation result changes.



param_grid =  {'model': [ LinearRegression() , GradientBoostingRegressor(n_estimators=20,random_state=10) ], 
              'num_periods_lagged':[3,26],
              'num_periods_diffed':[0],
              'weekday':[False],
              'month':[False],
              'holidays': [False],
              'rolling' : [[]]
             }

grid = ParameterGrid(param_grid)

error_lst = []

params_lst = []

for params in grid:
    predictions = predict_n_periods(series_=df_multistep_train,
                                    n_periods = 24,
                                    model = params['model'],
                                    num_periods_lagged = params['num_periods_lagged'],
                                    num_periods_diffed = params['num_periods_diffed'],
                                    weekday=params['weekday'],
                                    month= params['month'],
                                    target = "wp"
                                   )
    error_lst.append( mean_absolute_error(df_multistep_test[:24].wp,predictions))
    
error_lst
#param_grid = 

# grid = 

# for params in grid:
     # predictions =
                                    
# best_params =
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# CPU times: user 29.7 s, sys: 9.96 s, total: 39.7 s
# Wall time: 26.8 s
# [0.13204946088128727,
#  0.14300781032763685,
#  0.11321231768962903,
#  0.11605782785413117]

# %%
best_params = grid[2]

# %%
expected_hash = '4a4e3897467aca700e8b7f6bad8af525326b1299498c701bc3313b8056750bbb'
assert hashlib.sha256(str(best_params['model']).encode()).hexdigest() == expected_hash

expected_hash = '4e07408562bedb8b60ce05c1decfe3ad16b72230967de01f640b7e4729b49fce'
assert hashlib.sha256(str(best_params['num_periods_lagged']).encode()).hexdigest() == expected_hash

expected_hash = '5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91b46729d73a27fb57e9'
assert hashlib.sha256(str(best_params['num_periods_diffed']).encode()).hexdigest() == expected_hash

expected_hash = '60a33e6cf5151f2d52eddae9685cfa270426aa89d8dbc7dfb854606f1d1a40fe'
assert hashlib.sha256(str(best_params['weekday']).encode()).hexdigest() == expected_hash

expected_hash = '60a33e6cf5151f2d52eddae9685cfa270426aa89d8dbc7dfb854606f1d1a40fe'
assert hashlib.sha256(str(best_params['month']).encode()).hexdigest() == expected_hash

expected_hash = '60a33e6cf5151f2d52eddae9685cfa270426aa89d8dbc7dfb854606f1d1a40fe'
assert hashlib.sha256(str(best_params['holidays']).encode()).hexdigest() == expected_hash

expected_hash = '4f53cda18c2baa0c0354bb5f9a3ecbe5ed12ab4d8e11ba873c2f11161202b945'
assert hashlib.sha256(str(best_params['rolling']).encode()).hexdigest() == expected_hash

expected_hash = '7902699be42c8a8e46fbbb4501726517e86b22c56a189f7625a6da49081b2451'
assert hashlib.sha256(str(len(best_params)).encode()).hexdigest() == expected_hash

# %% [markdown]
# ### Q3.4 Train a model with the best combination and predict the test. Did the exogenous feature improve the MAE?

# %%
# We expect you to train the final model with train and val together.
# df_multistep_train_val = 
# predictions = 
# test_mae = 

# hint: Again, this should be mostly a copy paste from the exercise 2.3

# YOUR CODE HERE
raise NotImplementedError()

# %%
expected_hash = '5b0c19587a858f320eda9f4a1e31017027fb7f5a970424aa7e00b6e38eeac273'
assert hashlib.sha256(str(np.round(test_mae,5)).encode()).hexdigest() == expected_hash
